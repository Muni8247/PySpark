# %%
m=spark.read.table("workspace.munireddy.katigari_det")
display(m)

# %%
display(m.columns)

# %%
display(m.schema)

# %%
# %sql
insert into workspace.munireddy.katigari_det values
(8,"Rushi",51,"Male"),
(9,"Lakshmi Devi",50,"Female"),
(10,"Bali Reddy",87,"Male");

# %%
from pyspark.sql.functions import lit
m.withColumn("Adress",lit("Korrapadu")).show()

# %%
from pyspark.sql.functions import lit
m.withColumn("Total_Assest",lit(500000)).show()

# %%
from pyspark.sql.functions import lit
m=spark.read.table("workspace.munireddy.katigari_det")
m.withColumn("Total_Assest",lit(500000)).show()
m.printSchema()

# %%
display(m.columns)

# %%
muni=spark.read.table("workspace.munireddy.katigari_det")
display(muni.columns)

# %%
# %sql
alter table workspace.munireddy.katigari_det add column Salary int

# %%
# %sql
describe workspace.munireddy.katigari_det

# %%
# %sql
select * from workspace.munireddy.katigari_det

# %%
# %sql
update workspace.munireddy.katigari_det
set Salary=74000
where Gender="Male"

# %%
# %sql
update workspace.munireddy.katigari_det
set Salary=38000
where Gender="Female"

# %%
# %sql
select* from workspace.munireddy.katigari_det

# %%
from pyspark.sql.functions import col
y=spark.read.table("workspace.munireddy.katigari_det")
z=y.withColumn("Salary",col("Salary")+10000)
z.show()

# %%
x=y.withColumn("Bonus",col("Salary")*0.10)
x.show()

# %%
# %sql
select * from workspace.munireddy.katigari_det

# %%
from pyspark.sql.functions import col
z=spark.read.table("workspace.munireddy.katigari_det")

display(z.schema)

# %%
display(z.columns)

# %%
z.withColumn("Salary",col("Salary").cast("Float"))

# %%
display(z.schema)
