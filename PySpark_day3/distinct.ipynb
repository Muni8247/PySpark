# %%
m=spark.read.table("workspace.default.katigari_data")
display(m)

# %%
m1=m.distinct()
m1.show()

# %%
m2=m1.dropDuplicates(["2026_Increment"])
m2.show()

# %%
m2.printSchema()
m2.count()

# %%
display(m2)

# %%
n=spark.read.table("workspace.default.katigari_data")
display(n)

# %%
n1=n.sort("Age")
n1.show()

# %%
n2=n.orderBy("Age")
n2.show()
