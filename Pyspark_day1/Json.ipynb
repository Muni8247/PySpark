# %%
df2 = spark.read.table("muni_data.default.drivers")
display(df2)

# %%
df=spark.read.table("muni_data.default.drivers")
display(df)
df.show()
print("Total rows: ",df.count())
print("columns: ",df.columns)

# %%
df2 = spark.read.table("muni_data.default.drivers")
df2.printSchema()
print("Total Rows:", df2.count())
display(df2)
