# %% [markdown]
# CREATE DATAFRAME

# %%
df = spark.read.table("workspace.default.big_mart_sales")
display(df)

# %% [markdown]
# ###DATA FRAME HEADER

# %%
df1=spark.read.table("workspace.default.big_mart_sales")
display(df1.columns)

# %%
df2=spark.read.table("workspace.default.big_mart_sales")
print(df2.schema)

# %%
df3=spark.read.table("workspace.default.big_mart_sales")
df3.printSchema()

# %%
mn=spark.read.csv("/Workspace/Users/katigarimuni@gmail.com/Pyspark_day1",header=True)
display(mn)

# %%
m=spark.read.table("workspace.default.big_mart_sales")
display(m.columns)

# %%
display(m.schema)

# %%
m.printSchema()
