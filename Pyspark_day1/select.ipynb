# %%
df=spark.read.table("workspace.default.big_mart_sales")
display(df)

# %% [markdown]
# ###SELECT

# %%
m=spark.read.table("workspace.default.big_mart_sales")
m.printSchema()

# %%
m.select("Item_Fat_Content","Item_MRP").show()

# %%
m.select("Item_Type","Item_MRP").show()

# %%
m.select("Item_Type","Item_MRP").limit(20).show()

# %%
# %sql
create database Munireddy

# %%
# %sql
create table munireddy.katigari_det(Id int, Name1 varchar(20), Age int, Gender varchar(10))

# %%
# %sql
describe munireddy.katigari_det

# %%
m=spark.read.table("workspace.default.big_mart_sales")
m.show()

# %%
display(m)

# %%
m.select("Item_MRP").limit(10).show()

# %%
m.select("Item_MRP").limit(5).al

# %%
m.select(1:3).show

# %%
n=spark.read.table("workspace.default.big_mart_sales")

# %%
m.show()

# %%
display(m)

# %%
m.columns[1:4].limit(10).show()

# %%
m.select(m.columns[1:4]).show()

# %%
m.select(m.columns[0:3]).limit(5).show()

# %%
# %sql
describe workspace.munireddy.katigari_det

# %%
# %sql
insert into workspace.munireddy.katigari_det values
(1,"Muni Reddy",26,"Male"),
(2,"Swarna",29,"Female"),
(3,"Dileep",34,"Male"),
(4,"Ramu",38,"Male"),
(5,"Keerthi",40,"Female"),
(6,"Parthu",42,"Male"),
(7,"Naveen",31,"Male");

# %%
# %sql
select * from workspace.munireddy.katigari_det

# %%
a=spark.read.table("workspace.munireddy.katigari_det")
display(a)

# %%
display(a.columns)

# %%
display(a.schema)

# %%
a.select(a.columns[0:2]).show()
